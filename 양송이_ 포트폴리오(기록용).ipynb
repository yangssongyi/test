# %% [markdown]
# # 포트폴리오 전체 양식
# - 헤더: 이름, 연락처, github프로필
# - 요약: 자기소개, 장점, 특기분야
# - 경력:
# - 교육:
# - 기술, 자격증:
# - 프로젝트 요약:

# %% [markdown]
# # 목차
# A. 프로젝트 개요
#   - 프로젝트명
#   - 프로젝트를 들어가며
#   - 사용된 개발환경, 패키지, 툴, 응용프로그램
#   - 프로젝트의 목표
#
# B. 작업 계획
#   - gantt chart
#   - 작업 순서도
#
# C. 데이터 처리 및 분석
#   - phase 1. 데이터 수집/저장
#     - 1.1 데이터 소스 설명
#     - 1.2 데이터 수집 방법
#   - phase 2. 데이터 전처리
#     - 2.1 데이터 클렌징
#     - 2.2 결측치 처리
#     - 2.3 데이터 변환 및 정규화
#   - phase 3. 통계학적 분석/ 시각화
#     - 3.1 데이터 탐색
#     - 3.2 시각화 도구 및 기법
#     - 3.3 통계적 분석의 결론
#
# D. 모델링 및 평가
#   - phase 4. 머신러닝
#     - 4.1 모델 선택
#     - 4.2 데이터 준비/인코딩
#     - 4.3 모델 학습
#     - 4.4 모델 평가
#     - 4.5 예측결과 및 시각화
#     - 4.6 하이퍼 파라미터 튜닝
#     - 4.7 모델 개선
#   - 예측결과와 결론
#
# E. 응용 및 배포
#  - phase 5. 응용 어플리케이션
#   - 5.1 개요 및 알고리즘
#   - 5.2 플랫폼
#   - 5.3 백엔드 및 UI
#   - 5.4 테스트
#   - 5.5 소스코드
#   - 5.6 피드백
#
# F. 마무리

# %% [markdown]
# # A. 프로젝트 개요

# %% [markdown]
# ## 프로젝트 명: 음식 배달 앱 서비스와 도시별 건강 지표의 상관관계 분석을 통한 마케팅 전략 수립

# %% [markdown]
# ## 포지션: 음식 배달 앱 데이터 분석 기반 마케팅팀
#
# - 분석목적: 도시별 건강 트렌드에 맞춰 서비스 최적화 및 마케팅 전략을 수립
#
# - 예상 필요데이터: 음식 배달 서비스 데이터(배달 음식 주문 데이터, 사용자 정보, 지역별 음식 제공 현황), 도시별 건강지표(도시별 비만율, 음식 관련 질병 발생률 등), 도시 인프라 데이터(음식 접근성, 소득수준)
#
#
# ##분석내용:
#  - 가설: '배달 음식 앱을 자주 이용하는 지역의 비만율이 더욱 높을 것이다.' </br></br>
#
#  - '도시의 비만율이 높을수록 저칼로리 메뉴의 주문 비율은 낮을 것이다.'
#  - '비만율이 높은 지역에서 배달 음식의 배달 거리(소비자와 음식점 간 거리)가 짧을 것이다.'
# </br></br>
#  - 각 지역별 배달 음식 앱 서비스 이용량과 주 배달 음식을 비교
#
#
#  ### 고려할 사항:
#  - 시간대별 주문량: 특정 시간대(예: 저녁, 야식 시간대)에 주문이 집중되는 경향 분석
#  - 음식 종류 선호도: 지역별로 어떤 종류의 배달 음식을 더욱 선호하는지 분석
#  - 식재료 및 음식 건강도: 배달 음식의 영양 성분(칼로리, 지방, 당 등)에 따른 건강 영향 분석
#  - 도시 내 운동 시설 접근성: 운동 시설의 접근성이 배달 음식 사용과 건강 지표에 미치는 영향
#
# ### 해당 프로젝트를 통해 진행하려고 하는 마케팅 (임의):
# - 건강 식단 구독 서비스 제공 : 비만율이 높은 지역을 대상으로 저칼로리 또는 건강 식단 구독 서비스를 도입.
# 정기구독 고객에게 추가 할인 혜택 제공.
#
# - 특정 지역의 건강 문제를 반영한 캠페인 실행: 예) 비만율이 높은 지역에서는 “오늘은 샐러드 데이” 이벤트를 통해 건강한 음식을 저렴하게 제공.
#
# - 지역 기반 광고 타겟팅 :
# 비만율이 낮은 지역에서는 프리미엄 메뉴나 특별 메뉴 광고 강화.
# 비만율이 높은 지역에서는 저칼로리, 건강식 기반 광고에 집중.

# %% [markdown]
# ## 프로젝트를 들어가며

# %%
최근 몇 년간 크게 성장한 음식 배달 앱 서비스를 중심으로, 음식 배달 앱 서비스가 우리의 건강에 미치는 영향을 심층적으로 이해하기 위해 프로젝트를 기획하였습니다.
프로젝트를 통해

# %% [markdown]
# ### 사용된 개발환경, 패키지, 툴, 응용프로그램

# %%
프로그래밍 언어: Python3
데이터 전처리: pandas, numpy, matplotlib, seaborn
데이터 분석: pandas, numpy, matplotlib, seaborn
딥러닝 프레임워크: 텐서플로 Sequencial
한글처리 형태소 패키지: konlpy-Okt
머신러닝 패키지: sklearn
머신러닝 알고리즘: 로지스틱 회귀
LLM: llama3

# %% [markdown]
# ## 프로젝트의 목표

# %% [markdown]
# # B. 작업계획

# %% [markdown]
# ## Gantt chart

# %% [markdown]
# ## 작업순서도

# %% [markdown]
# 회의
# 자료조사
# 분석 -> 통계분석(1,2,3)
# 머신러닝 전처리
# 패키지 설치

# %% [markdown]
# ## 응용프로그램 순서도

# %% [markdown]
# 프로그램시작 -> 수치가 10이 넘는가? ->(네) phase2
#              ->(아니오) for

# %% [markdown]
# #C. 데이터 처리 및 분석

# %% [markdown]
# ### 분석 전략
#
# # 데이터 처리 및 분석 단계 요약
#
# | Phase              | 세부 단계            | 내용                                                                                           |
# |--------------------|---------------------|----------------------------------------------------------------------------------------------|
# | 1. 데이터 수집/저장 | 1.1 데이터 소스 설명 | - 음식 배달 앱: 주문 내역, 사용자 데이터<br><br>- 도시별 건강 지표: 비만율, 당뇨병, 질병 발생률 등 공공 데이터<br><br>- 도시 인프라 데이터: 음식 접근성, 소득 수준|
# |                    | 1.2 데이터 수집 방법 | - API, 파일(CSV/Excel/JSON) 다운로드                           |
# | 2. 데이터 전처리   | 2.1 데이터 클렌징    | - 중복 데이터 제거<br><br>- 이상치 탐지<br><br>- 데이터 통합(공통 키로 병합)                          |
# |                    | 2.2 결측치 처리      | - 결측치 삭제 또는 대체(평균값, 중앙값, 모델 예측 등)                                         |
# |                    | 2.3 데이터 변환/정규화 | - 스케일링(Min-Max, Standard Scaling)<br><br>- 범주형 데이터 인코딩<br><br>- 시간 데이터 변환         |
# | 3. 통계/시각화     | 3.1 데이터 탐색      | - 기초 통계량(평균, 표준편차 등)<br><br>- 상관 분석(Pearson/Spearman)                             |
# |                    | 3.2 시각화 도구/기법 | - 도구: Python(Matplotlib, Seaborn), Tableau<br><br>- 히트맵, 분포도, 시계열 분석, 지도 시각화    |
# |                    | 3.3 분석 결론        | - 상관관계 요약<br><br>- 가설 검정<br><br>- 건강 지표와 주문 패턴을 기반으로 마케팅 전략 수립         |

# %% [markdown]
# ## Phase1. 데이터 수집 및 저장

# %% [markdown]
# - 공개데이터 세트
#
# 1.

# %% [markdown]
# ### 1.1 데이터 소스 설명

# %%
(데이터의 출처와 데이터셋의 특성을 설명합니다.)

1.음식 배달 서비스 데이터
- 주문 데이터: 도시별 음식 배달 주문 건수, 시간대, 음식 종류(패스트푸드, 건강식 등), 배달 거리
- 사용자 정보: 연령, 성별, 소득 수준 등의 인구통계학적 정보
- 지역별 음식 제공 현황: 레스토랑 및 배달 가능한 음식점의 밀집도, 음식 카테고리 분포

2.도시별 건강지표 (건강보험공단 공개자료 찾아보기)
- 비만율: 도시별 인구의 비만율.
- 질병 발생률: 당뇨, 고혈압, 심장병 등 음식과 관련된 질병의 발생 빈도
- 운동량 데이터: 도시 주민들의 평균 신체 활동 시간
- 영양 섭취 통계: 도시별 영양소 섭취 수준, 특히 칼로리, 지방, 설탕, 소금 등의 소비량
- 사망률: 음식과 관련된 질병으로 인한 사망률 데이터

3. 도시 인프라 데이터
- 음식 접근성: 도시 내 슈퍼마켓, 건강식품점, 패스트푸드점의 밀도
- 소득 수준 : 음식 선택과 건강에 영향을 미칠 수 있는 인구통계 데이터

# %%
(데이터의 출처와 데이터셋의 특성을 설명합니다.)

1.음식 배달 서비스 데이터
- 주문 데이터: 도시별 음식 배달 주문 건수, 음식 종류(패스트푸드, 건강식 등), 평균 배달 시간, 배달 거리
# 업종-거리 구간 배달 건수 : 2019 ~ 2021 [주문 연도, 월, 도시, 시군구, 배달거리, 배달 건수 ]
# 업종 목적지별 평균 주문금액 : 2019 ~ 2022 [주문일자, 주문시간, 음식 종류, 도시, 시군구, 주문 금액]
# 업종 목적지별 배달 주문건수 : 2019 ~ 2022 [주문 날짜, 음식 종류, 도시, 시군구, 주문건수]

- 사용자 정보: 연령, 성별, 소득 수준 등의 인구통계학적 정보
# 주문지역 인구 특성: [기준연월, 시군구코드, 시도명, 시군구명, 연령단위, 총인구수, 남성인구수, 여성인구수]

- 지역별 음식 제공 현황: 레스토랑 및 배달 가능한 음식점의 밀집도, 음식 카테고리 분포
# 지역별 음식점 소비기반 트렌드: [도시, 시군구, 행정동, 음식시설코드 음식시설명, 분류코드, 음식시설수, 인구수, 파일명, 기준일자]

# 지역 - 업종별 결제 정보: [날짜, HRLY_TIME(어떤 것을 나타내는지 확인 어려움), 음식 종류, 도시, 시군구, 결제종류번호?]

*데이터 출처 :
KT 통합 빅데이터 플랫폼
https://www.bigdata-telecom.kr/invoke/SOKBP0701/?srchRsltsrch=%EB%B0%B0%EB%8B%AC
문화 빅데이터 플랫폼
https://www.bigdata-culture.kr/bigdata/user/main.do

2.도시별 건강지표 (건강보험공단 공개자료 찾아보기)
- 비만율: 도시별 인구의 비만율.
# 건강결과_유병률_비만 (2018~2022)
# 건강결과_비만유병률(체질량기준)(2019~2022)

데이터 출처 :
질병관리청 만성 질환 건강통계 (비만유병률)
https://chs.kdca.go.kr/cdhs/biz/pblcVis/details.do?ctgrSn=31
HIRA 빅데이터개방포털 (지역별 당뇨병/지역별 비만 진료현황)
https://opendata.hira.or.kr/home.do

- 질병 발생률: 당뇨, 고혈압, 심장병 등 음식과 관련된 질병의 발생 빈도
# 각 질병에 따른 환자주소지별 현황
# 지역별 당뇨병, 비만 진료현황 (2019~2023)

- 운동량 데이터: 도시 주민들의 평균 신체 활동 시간
#인구 10만명당 체육시설의 수 (2018~2022)
#시군구 별 건강생활실천율 (2021~2023)

KOSIS
https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1YL2401&conn_path=D9&vw_cd=MT_GTITLE01

- 영양 섭취 통계: 도시별 영양소 섭취 수준, 특히 칼로리, 지방, 설탕, 소금 등의 소비량
#지역별_영양소별 평균 섭취량 (2019~2021)
#지역별_영양소별 평균 섭취량(2016~2018)
#시도별 _ 건강영양 통계 식품 섭취량 분석

국민영양통계
https://www.khidi.or.kr/kps/dhraStat/result5?menuId=MENU01657&year=2021

- 사망률: 음식과 관련된 질병으로 인한 사망률 데이터
#사망원인별 사망률 추이 (2018~2023)

데이터 출처:
지표누리 e-나라지표
https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=1012

3. 도시 인프라 데이터
- 음식 접근성: 도시 내 슈퍼마켓, 건강식품점, 패스트푸드점의 밀도
#

- 소득 수준 : 음식 선택과 건강에 영향을 미칠 수 있는 인구통계 데이터
# 가구별 소득(시도별) (2017~2022)
# 1인당 지역총소득(시도별) (2018~2022)

국가 통계 포털
https://kosis.kr/visual/eRegionJipyo/themaJipyo/eRegionJipyoThemaJipyoView.do?themaId=A_02_01

# %% [markdown]
# ###1.2 데이터 수집 방법

# %%
- 각 통계 포털을 이용해 주제에 맞는 데이터 수집 진행

*데이터 출처 :
KT 통합 빅데이터 플랫폼
https://www.bigdata-telecom.kr/invoke/SOKBP0701/?srchRsltsrch=%EB%B0%B0%EB%8B%AC
문화 빅데이터 플랫폼
https://www.bigdata-culture.kr/bigdata/user/main.do

질병관리청 만성 질환 건강통계 (비만유병률)
https://chs.kdca.go.kr/cdhs/biz/pblcVis/details.do?ctgrSn=31
HIRA 빅데이터개방포털 (지역별 당뇨병/지역별 비만 진료현황)
https://opendata.hira.or.kr/home.do

KOSIS
https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1YL2401&conn_path=D9&vw_cd=MT_GTITLE01

국민영양통계
https://www.khidi.or.kr/kps/dhraStat/result5?menuId=MENU01657&year=2021

지표누리 e-나라지표
https://www.index.go.kr/unity/potal/main/EachDtlPageDetail.do?idx_cd=1012

국가 통계 포털
https://kosis.kr/visual/eRegionJipyo/themaJipyo/eRegionJipyoThemaJipyoView.do?themaId=A_02_01

# %% [markdown]
# ## Phase2. 데이터 전처리

# %% [markdown]
# ### 데이터 정제 - 1. 배달앱 주문 건수

# %% [markdown]
# ### 2.1 데이터 클렌징

# %% [markdown]
# ### 2.2 결측치 처리

# %% [markdown]
# ### 2.3 데이터 변환 및 정규화

# %% [markdown]
# ## Phase3. 통계학적 분석 및 시각화

# %% [markdown]
# ### 3.1 데이터 탐색

# %% [markdown]
# - ---를 확인하고싶 - > 1,2,를 이용하여 새로운열 . 를 만든다

# %%
(데이터의 특성과 분포를 파악하고, 주요 통계치를 분석하여 데이터에 대한 전반적인 이해를 돕습니다.)

# %% [markdown]
# ### 3.2 시각화 도구 및 기법

# %% [markdown]
# ### 3.3 통계적 분석의 결론

# %% [markdown]
# # D.모델링 및 평가

# %% [markdown]
# ## phase 4. 머신러닝

# %% [markdown]
# ###4.1 모델 선택

# %% [markdown]
# ###4.2 데이터 준비/인코딩

# %%
(데이터 전처리와 비슷하나, 이번엔 머신러닝 및 딥러닝을 위한 전처리입니다. 데이터삭제, 카테고리화, 수치화, 인코딩 등이 포함됩니다. )

# %% [markdown]
# ###4.3 모델 학습

# %% [markdown]
# ###4.4 모델 평가

# %%
(다양한 평가 지표를 사용하여 모델의 성능을 평가합니다.)

# %% [markdown]
# ###4.5 예측결과 및 시각화

# %% [markdown]
# ###4.6 하이퍼 파라미터 튜닝

# %%
(모델의 성능을 최적화하기 위한 하이퍼파라미터 튜닝 과정을 설명합니다.)

# %% [markdown]
# ###4.7 모델 개선

# %%
(모델의 성능을 개선하기 위해 시도한 방법과 그 결과를 설명합니다.)

# %% [markdown]
# ###4.8 예측결과와 결론

# %% [markdown]
# # E. 응용 및 배포

# %%
(모델을 실제 환경에 배포하는 과정과 그에 따른 통합 작업을 설명합니다.)

# %% [markdown]
# ## phase 5. 응용 어플리케이션 (선택)

# %% [markdown]
# ###5.1 개요 및 알고리즘

# %% [markdown]
# ###5.2 플랫폼

# %% [markdown]
# ###5.3 UI

# %% [markdown]
# ###5.4 테스트

# %% [markdown]
# ###5.5 소스코드

# %% [markdown]
# ###5.6 피드백

# %% [markdown]
# # F.마무리

# %%
( 프로젝트의 전체적인 성과와 배운 점을 정리하고, 향후 개선 사항이나 추가할 내용에 대해 간략히 설명합니다.)
